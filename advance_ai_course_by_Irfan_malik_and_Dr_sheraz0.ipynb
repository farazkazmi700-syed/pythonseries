# %% [markdown]
# <a href="https://colab.research.google.com/github/farazkazmi700-syed/pythonseries/blob/main/advance_ai_course_by_Irfan_malik_and_Dr_sheraz0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# faraz <class 'str'>
# 25 <class 'int'>
# 5.75 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# # Basic Programming concept

# %% [markdown]
# #  right variables diclration

# %%
student_name = "faraz"
student_height = 5.75
student_age = 25

student_id =  True
print(student_name, type(student_name))
print(student_age, type (student_age))
print(student_height, type(student_height))
print(student_id, type(student_id))
# Out:
# faraz <class 'str'>
# 25 <class 'int'>
# 5.75 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# # Data types
# # String Manipulation

# %%
#1. Pyhthon string
a=" My name is syed faraz kazmi this course is fir enhancing theh ai learnings"
print(a.upper())
print(a.lower())
# Multilin strings
print(""" \n My name is syed faraz kazmi this course is fir enhancing theh ai learnings
My name is syed faraz kazmi this course is for enhancing theh ai learnings
My name is syed faraz kazmi this course is for enhancing theh ai learnings
My name is syed faraz kazmi this course is for enhancing theh ai learnings
My name is syed faraz kazmi this course is for enhancing theh ai learnings""")
# Remove white space
b=" My name is syed faraz kazmi this course is for enhancing theh ai   learnings"
print(b.strip())
# replace string
c=" My name is syed faraz kazmi this course is for enhancing theh ai learnings"
print(c.replace("ai","AI Engineer"))
# split string
d=" My name, is syed faraz kazmi ,this course is for enhancing theh ai learnings"
print(d.split())
# 2.  Python list
name_list = ["faraz","hamza","ali"]
print(name_list)
# list length ,items , slicing and acces element
name_list = ["faraz","hamza","ali"]
print(len(name_list))
print(name_list[0])
print(name_list[1])
print(name_list[-1])

list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]
print(list1)
print(list2.append(10))
print(list2)
print(list3)
list4 = ["kingdom of qatar","UAE"]
list4.reverse()
print(list4)

list1 = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(list1[1:4])
# for sorting
list1 = ["apple", "mango", "cherry", "orange", "kiwi", "avacado", "mango"]
list1.sort()
print(list1)


# 3.  Python tuple | Immutable
tup = (5,10,15,20,25)
print(tup)
# 5.  Python set
computer_class = {"faraz","hamza","ali","FARAZ","FARAZ"}
print(computer_class)
# pyhton dictionary
# key values
this_dict = {
  "brand": "honda",
  "model": "civic",
  "year": 2008
}
print(this_dict)
print(this_dict["brand"])
# Out:
#  MY NAME IS SYED FARAZ KAZMI THIS COURSE IS FIR ENHANCING THEH AI LEARNINGS
#  my name is syed faraz kazmi this course is fir enhancing theh ai learnings
#
#  My name is syed faraz kazmi this course is fir enhancing theh ai learnings
# My name is syed faraz kazmi this course is for enhancing theh ai learnings
# My name is syed faraz kazmi this course is for enhancing theh ai learnings
# My name is syed faraz kazmi this course is for enhancing theh ai learnings
# My name is syed faraz kazmi this course is for enhancing theh ai learnings
# My name is syed faraz kazmi this course is for enhancing theh ai   learnings
#  My name is syed faraz kazmi this course is for enhancing theh AI Engineer learnings
# ['My', 'name,', 'is', 'syed', 'faraz', 'kazmi', ',this', 'course', 'is', 'for', 'enhancing', 'theh', 'ai', 'learnings']
# ['faraz', 'hamza', 'ali']
# 3
# faraz
# hamza
# ali
# ['apple', 'banana', 'cherry']
# None
# [1, 5, 7, 9, 3, 10]
# [True, False, False]
# ['UAE', 'kingdom of qatar']
# ...

# %% [markdown]
# # Operators
# # These are funtion that can be applied and it returns value

# %% [markdown]
# # 5.  arthmatic operators

# %%
add = print(10+5)
sub = print(10-5)
multiply = print(10*5)
divide = print(10/5)
modulous = print(10%5)

#example area of rectangle
# length of variable
length = 10
# width of variable
width = 5
#  area of rectangle
area = length * width
print("This is the area of rectangle ",area)

# Example volume of a cube
#  Length of variable
l = 20
#  Volume of cube
volume = l*l*l
print("This is the volume of cube : ",volume)
# Out:
# 15
# 5
# 50
# 2.0
# 0
# This is the area of rectangle  50
# This is the volume of cube :  8000

# %% [markdown]
# # 6. Logical Operatots

# %%
equalto = print(10==5)
not_equalto = print(10!=5)
greaterthan = print(10>5)
lessthan = print(10<5)
x = print(15) and print(5)
y  = print(10 or 5)
z = not(4>5)
print(z)
# to build the scenrio to use the logical operator
# Out:
# False
# True
# True
# False
# 15
# 10
# True
