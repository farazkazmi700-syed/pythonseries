# %%
name = "Faraz Kazmi"
name
# Out:
# 'Faraz Kazmi'

# %% [markdown]
# # Input&Typecasting

# %%
name = input("Enter your name: ")
age =  input("Enter your age: ")
height = input("Enter your age: ")
man = (f"your name is {name} and age is {age} and height {height}")
man

# %% [markdown]
# # Conditions (if-else)

# %%
password = int(input("Enter your password: "))
if password == 1234:
    print("Access Granted")
else :
    print("Invalid password")
# Out:
# Access Granted

# %% [markdown]
# # Functions

# %%
def tax_calculation(amount):
    return amount*0.2
tax_calculation(1000)
# Out:
# 200.0

# %%
def add(a,b):
    return a+b
add(2,3)
# Out:
# 5

# %% [markdown]
# #   List

# %%
city = ["lahore","karachi","islamabad"]
for i in city:
    print (city)

city.append("Mianwali")
city
# Out:
# ['lahore', 'karachi', 'islamabad']
# ['lahore', 'karachi', 'islamabad']
# ['lahore', 'karachi', 'islamabad']
# ['lahore', 'karachi', 'islamabad', 'Mianwali']

# %%
nums = [1, 2, 3, 4, 5]

result = [n**n for n in nums if n % 2 == 0]

print(result)

nums = [1, 2, 3, 4, 5]

result = [n*n for n in nums if n % 2 == 0]

print(result)
# Out:
# [4, 256]
# [4, 16]

# %%
marks = [30,40, 80, 55, 90]

result = ["Pass" if m >= 40 else "Fail" for m in marks]

print(result)
# Out:
# ['Fail', 'Pass', 'Pass', 'Pass', 'Pass']

# %% [markdown]
# # Dictionary

# %%
user = {"name": "Faraz", "age": 24}

user.get("name")
user.get("age")
# Out:
# 24

# %% [markdown]
# # set

# %%
emails = {"a@gmail.com", "b@gmail.com", "a@gmail.com"}
emails
# Out:
# {'a@gmail.com', 'b@gmail.com'}

# %%
num =   [1,2,3,4,5,6]
even = list(filter(lambda x: x%2==0,num))
even
# Out:
# [2, 4, 6]

# %% [markdown]
# # OOPs

# %%
class Student:
    def __init__(self,name,age,city):
        self.name = name
        self.age = age
        self.city = city
    def show(self):
        print("Your name is: " ,self.name,"Your age is : ",self.age, "Your city is : ",self.city)
s1 = Student("Faraz",25,"Mianwali")
s1.show()
# Out:
# Your name is:  Faraz Your age is :  25 Your city is :  Mianwali

# %% [markdown]
# # encapsulation

# %%
class Bank:
    def __init__(self):
        self.__balance = 1000   # private

    def deposit(self, amount):
        self.__balance += amount

    def show_balance(self):
        print(self.__balance)

b = Bank()
b.deposit(5000)
b.show_balance()
# Out:
# 6000

# %% [markdown]
# # Inhertitance

# %%
class Animal:
    def speak(self): 
        print("Animal speaks")

class Dog(Animal):
    def bark(self):
        print("Dog barks")
class Cat(Animal):
    def catsound(self):
        print("Meo Meo")

C = Cat()
A = Animal()

C.speak()
C.catsound()
# Out:
# Animal speaks
# Meo Meo

# %% [markdown]
# # polymorphism

# %%
class Animal:
    def sound(self):
        print("Animal sound")

class Cat(Animal):
    def sound(self):
        print("Meow")

c = Cat()
a = Animal()
a.sound()
c.sound()
# Out:
# Animal sound
# Meow

# %% [markdown]
# # abstraction

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def area(self):
        print("Circle area")

c = Circle()
c.area()
# Out:
# Circle area

# %% [markdown]
# # defult constructor

# %%
class A:
    def __init__(self,age):
        self.age = age
        print("Default constructor", self.age)
a=A(23)
# Out:
# Default constructor 23

# %%
nums = [1, 2, 3, 4]
result = list(map(lambda x: x * 2, nums))
print(result)
# Out:
# [2, 4, 6, 8]

# %%
from functools import reduce

nums = [1, 2, 3, 4]

result = reduce(lambda x, y: x * y, nums)
print(result)
# Out:
# 24
